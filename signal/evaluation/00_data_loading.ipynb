# %%
import numpy as np
data_dict = np.load("01_ecg_ppg.npy", allow_pickle=True).item()
print(data_dict.keys())
print(data_dict['chest'].keys())

ecg = data_dict['chest']['ecg']
ppg = data_dict['wrist']['ppg G']

print(ecg.shape)
print(ppg.shape)
# Out:
# dict_keys(['chest', 'head', 'ankle', 'wrist'])
# dict_keys(['ecg', 'ppg G', 'ppg IR', 'ppg R'])
# (6428816,)
# (6428816,)

# %%
import matplotlib.pyplot as plt
plt.plot(ecg[4000000:4001000])
plt.show()

# %%
plt.plot(ppg[4000000:4001000])
plt.show()
